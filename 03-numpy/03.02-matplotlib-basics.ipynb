# %% [markdown]
# # Matplotlib 基础

# %% [markdown]
# 在使用**Numpy**之前，需要了解一些画图的基础。
#
# **Matplotlib**是一个类似**Matlab**的工具包，主页地址为
#
# http://matplotlib.org
#
# 导入 `matplotlib` 和 `numpy`：

# %%
# %pylab
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# `%matplotlib inline`使用此后端，绘图命令的输出将在Jupyter笔记本之类的前端内联显示，直接位于生成该代码的代码单元下方。然后，生成的图也将存储在笔记本文档中。

# %% [markdown]
# ## plot 二维图

# %% [markdown]
# ```python
# plot(y)
# plot(x, y)
# plot(x, y, format_string)
# ```
#
# 只给定 `y` 值，默认以下标为 `x` 轴：

# %%
# %matplotlib inline
x = linspace(0, 2 * pi, 50)
plot(sin(x))

# %% [markdown]
# 给定 `x` 和 `y` 值：

# %%
plot(x, sin(x))

# %% [markdown]
# 多条数据线：

# %%
plot(x, sin(x),
    x, sin(2 * x))
# Out:
# [<matplotlib.lines.Line2D at 0x7f5059ee5070>,
#  <matplotlib.lines.Line2D at 0x7f5059ee50a0>]

# %% [markdown]
# 使用字符串，给定线条参数：

# %%
plot(x, sin(x), 'r-^')

# %% [markdown]
# 多线条：

# %%
plot(x, sin(x), 'b-o',
    x, sin(2 * x), 'r-^')
# Out:
# [<matplotlib.lines.Line2D at 0x7f5059fd8ac0>,
#  <matplotlib.lines.Line2D at 0x7f5059fd8790>]

# %% [markdown]
# 更多参数设置，请查阅帮助。事实上，字符串使用的格式与**Matlab**相同。

# %% [markdown]
# ## scatter 散点图

# %% [markdown]
# ```python
# scatter(x, y)
# scatter(x, y, size)
# scatter(x, y, size, color)
# ```
#
# 假设我们想画二维散点图：

# %%
plot(x, sin(x), 'bo')

# %% [markdown]
# 可以使用 `scatter` 达到同样的效果：

# %%
scatter(x, sin(x))

# %% [markdown]
# 事实上，scatter函数与**Matlab**的用法相同，还可以指定它的大小，颜色等参数：

# %%
x = rand(200)
y = rand(200)
size = rand(200) * 30
color = rand(200)
scatter(x, y, size, color)
# 显示颜色条
colorbar()

# %% [markdown]
# ## 多图

# %% [markdown]
# 使用figure()命令产生新的图像：

# %%
t = linspace(0, 2*pi, 50)
x = sin(t)
y = cos(t)
figure()
plot(x)
figure()
plot(y)

# %% [markdown]
# 或者使用 `subplot` 在一幅图中画多幅子图：
#
#     subplot(row, column, index)

# %%
subplot(1, 2, 1)
plot(x)
subplot(1, 2, 2)
plot(y)

# %% [markdown]
# ## 向图中添加数据

# %% [markdown]
# 默认多次 `plot` 会叠加：

# %%
plot(x)
plot(y)

# %% [markdown]
# ## 标签

# %% [markdown]
# 可以在 `plot` 中加入 `label` ，使用 `legend` 加上图例：

# %%
plot(x, label='sin')
plot(y, label='cos')
legend()

# %% [markdown]
# 或者直接在 `legend`中加入：

# %%
plot(x)
plot(y)
legend(['sin', 'cos'])

# %% [markdown]
# ## 坐标轴，标题，网格

# %% [markdown]
# 可以设置坐标轴的标签和标题：

# %%
plot(x, sin(x))
xlabel('radians')
# 可以设置字体大小
ylabel('amplitude', fontsize='large')
title('Sin(x)')
# Out:
# Text(0.5, 1.0, 'Sin(x)')

# %% [markdown]
# 用 'grid()' 来显示网格：

# %%
plot(x, sin(x))
xlabel('radians')
ylabel('amplitude', fontsize='large')
title('Sin(x)')
grid()

# %% [markdown]
# ## 清除、关闭图像

# %% [markdown]
# 清除已有的图像使用：
#
#     clf()
#
# 关闭当前图像：
#
#     close()
#
# 关闭所有图像：
#
#     close('all')

# %% [markdown]
# ## imshow 显示图片

# %% [markdown]
# 灰度图片可以看成二维数组：

# %%
# 导入lena图片
def lena():
    import pickle, os
    fname = os.path.join('./img/lena.dat')
    f = open(fname,'rb')
    lena = array(pickle.load(f))
    f.close()
    return lena
img = lena()
img
# Out:
# array([[162, 162, 162, ..., 170, 155, 128],
#        [162, 162, 162, ..., 170, 155, 128],
#        [162, 162, 162, ..., 170, 155, 128],
#        ...,
#        [ 43,  43,  50, ..., 104, 100,  98],
#        [ 44,  44,  55, ..., 104, 105, 108],
#        [ 44,  44,  55, ..., 104, 105, 108]])

# %% [markdown]
# 我们可以用 `imshow()` 来显示图片数据：

# %%
imshow(img,
       # 设置坐标范围
      extent = [-25, 25, -25, 25],
       # 设置colormap
      cmap = cm.bone)
colorbar()

# %% [markdown]
# 更多参数和用法可以参阅帮助。

# %% [markdown]
# 这里 `cm` 表示 `colormap`，可以看它的种类：

# %%
dir(cm)
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r',
#  'CMRmap',
#  'CMRmap_r',
#  'Dark2',
#  'Dark2_r',
#  'GnBu',
#  'GnBu_r',
#  'Greens',
#  'Greens_r',
#  'Greys',
#  'Greys_r',
#  'LUTSIZE',
#  'MutableMapping',
#  'OrRd',
#  'OrRd_r',
#  'Oranges',
#  'Oranges_r',
#  'PRGn',
#  'PRGn_r',
#  'Paired',
#  'Paired_r',
#  'Pastel1',
#  'Pastel1_r',
#  'Pastel2',
#  'Pastel2_r',
#  'PiYG',
#  'PiYG_r',
#  'PuBu',
#  'PuBuGn',
#  'PuBuGn_r',
#  'PuBu_r',
#  'PuOr',
#  'PuOr_r',
#  'PuRd',
#  'PuRd_r',
#  'Purples',
#  'Purples_r',
#  'RdBu',
#  'RdBu_r',
#  'RdGy',
#  'RdGy_r',
#  'RdPu',
#  'RdPu_r',
#  'RdYlBu',
#  'RdYlBu_r',
#  'RdYlGn',
#  'RdYlGn_r',
#  'Reds',
#  'Reds_r',
#  'ScalarMappable',
#  'Set1',
#  'Set1_r',
#  'Set2',
#  'Set2_r',
#  'Set3',
#  'Set3_r',
#  'Spectral',
#  'Spectral_r',
#  'Wistia',
#  'Wistia_r',
#  'YlGn',
#  'YlGnBu',
#  'YlGnBu_r',
#  'YlGn_r',
#  'YlOrBr',
#  'YlOrBr_r',
#  'YlOrRd',
#  'YlOrRd_r',
#  '_DeprecatedCmapDictWrapper',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_cmap_registry',
#  '_gen_cmap_registry',
#  '_reverser',
#  'afmhot',
#  'afmhot_r',
#  'autumn',
#  'autumn_r',
#  'binary',
#  'binary_r',
#  'bone',
#  'bone_r',
#  'brg',
#  'brg_r',
#  'bwr',
#  'bwr_r',
#  'cbook',
#  'cividis',
#  'cividis_r',
#  'cmap_d',
#  'cmaps_listed',
#  'colors',
#  'cool',
#  'cool_r',
#  'coolwarm',
#  'coolwarm_r',
#  'copper',
#  'copper_r',
#  'cubehelix',
#  'cubehelix_r',
#  'datad',
#  'flag',
#  'flag_r',
#  'functools',
#  'get_cmap',
#  'gist_earth',
#  'gist_earth_r',
#  'gist_gray',
#  'gist_gray_r',
#  'gist_heat',
#  'gist_heat_r',
#  'gist_ncar',
#  'gist_ncar_r',
#  'gist_rainbow',
#  'gist_rainbow_r',
#  'gist_stern',
#  'gist_stern_r',
#  'gist_yarg',
#  'gist_yarg_r',
#  'gnuplot',
#  'gnuplot2',
#  'gnuplot2_r',
#  'gnuplot_r',
#  'gray',
#  'gray_r',
#  'hot',
#  'hot_r',
#  'hsv',
#  'hsv_r',
#  'inferno',
#  'inferno_r',
#  'jet',
#  'jet_r',
#  'ma',
#  'magma',
#  'magma_r',
#  'mpl',
#  'nipy_spectral',
#  'nipy_spectral_r',
#  'np',
#  'ocean',
#  'ocean_r',
#  'pink',
#  'pink_r',
#  'plasma',
#  'plasma_r',
#  'prism',
#  'prism_r',
#  'rainbow',
#  'rainbow_r',
#  'register_cmap',
#  'revcmap',
#  'seismic',
#  'seismic_r',
#  'spring',
#  'spring_r',
#  'summer',
#  'summer_r',
#  'tab10',
#  'tab10_r',
#  'tab20',
#  'tab20_r',
#  'tab20b',
#  'tab20b_r',
#  'tab20c',
#  'tab20c_r',
#  'terrain',
#  'terrain_r',
#  'turbo',
#  'turbo_r',
#  'twilight',
#  'twilight_r',
#  'twilight_shifted',
#  'twilight_shifted_r',
#  'viridis',
#  'viridis_r',
#  'winter',
#  'winter_r']

# %% [markdown]
# 使用不同的 `colormap` 会有不同的显示效果。

# %%
imshow(img, cmap=cm.RdGy_r)

# %% [markdown]
# ## 从脚本中运行

# %% [markdown]
# 在脚本中使用 `plot` 时，通常图像是不会直接显示的，需要增加 `show()` 选项，只有在遇到 `show()` 命令之后，图像才会显示。

# %% [markdown]
# ## 直方图

# %% [markdown]
# 从高斯分布随机生成1000个点得到的直方图：

# %%
hist(randn(1000))
# Out:
# (array([  8.,  33.,  82., 170., 262., 223., 142.,  58.,  16.,   6.]),
#  array([-3.21620978, -2.54713387, -1.87805795, -1.20898204, -0.53990612,
#          0.1291698 ,  0.79824571,  1.46732163,  2.13639754,  2.80547346,
#          3.47454937]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 更多例子请参考下列网站：
#
# https://matplotlib.org/2.0.2/gallery.html
